# %%
! pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# ✅ Set your filename (no extension)
file_name = 'bitcoin2018_LSTM_tanh_relu'

# ✅ Load the result CSV
csv_path = os.path.join('result', file_name + '.csv')
df = pd.read_csv(csv_path)

# ✅ Optional: preview columns
print("🔍 CSV Columns:", df.columns.tolist())

# ✅ Plotting loss values if available
plt.figure(figsize=(20, 10))

# If your CSV has `epoch`, `loss`, and `val_loss`
if 'val_loss' in df.columns:
    sns.boxplot(data=df[['loss', 'val_loss']])
    plt.title(f"📊 Box Plot of Training and Validation Loss - {file_name}")
else:
    # If the CSV has multiple columns for different runs (like different L1/L2 configs)
    df = df.set_index(df.columns[0])  # set epoch or unnamed column as index
    df.boxplot()
    plt.title(f"📊 Box Plot of Multiple LSTM Configurations - {file_name}")

plt.yscale('log')
plt.ylabel('Loss (log scale)')
plt.grid(True)

# ✅ Save and show
plot_path = os.path.join('result', file_name + '_boxplot.png')
plt.savefig(plot_path)
plt.show()

print(f"✅ Box plot saved to: {plot_path}")
# Out:
# 🔍 CSV Columns: ['epoch', 'loss', 'val_loss']
# C:\Users\Prakriti\AppData\Local\Temp\ipykernel_22236\4144850841.py:35: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.savefig(plot_path)
# c:\Users\Prakriti\Desktop\crypto\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ✅ Box plot saved to: result\bitcoin2018_LSTM_tanh_relu_boxplot.png

# %%
import pandas as pd
import seaborn as sns
file_name = 'lstm_kernel_reg'
df = pd.read_csv('result/'+file_name+'.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 import seaborn as sns
#       3 file_name = 'lstm_kernel_reg'
# ----> 4 df = pd.read_csv('result/'+file_name+'.csv')
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# === [📁 Config] ===
file_name = 'bitcoin2018_LSTM_tanh_relu'  # change if you used a different name
csv_path = os.path.join('result', file_name + '.csv')

# === [📄 Load CSV] ===
df = pd.read_csv(csv_path)

# === [🔍 Show Columns] ===
print("Columns in CSV:", df.columns.tolist())

# === [📊 Boxplot of Loss vs Val_Loss] ===
plt.figure(figsize=(16, 8))
sns.boxplot(data=df[['loss', 'val_loss']])
plt.title('Boxplot of Training and Validation Loss')
plt.ylabel('MSE Loss')
plt.yscale('log')  # set to log scale for better visibility
plt.grid(True)

# === [💾 Save Plot] ===
plot_path = os.path.join('result', file_name + '_boxplot.png')
plt.savefig(plot_path)
plt.show()

print(f"✅ Saved boxplot to: {plot_path}")
# Out:
# Columns in CSV: ['epoch', 'loss', 'val_loss']
# ✅ Saved boxplot to: result\bitcoin2018_LSTM_tanh_relu_boxplot.png
